# %%
import pandas as pd
import gurobipy as gp
from gurobipy import GRB
import scipy.sparse as sp
import numpy as np

# %%
brews_df = pd.read_pickle('data/brews_with_costs.pkl')
ingredients_df = pd.read_pickle('data/ingredients.pkl')
brews_df
# Out:
#       first_ingredient       second_ingredient     third_ingredient  \
# 0      Abecean Longfin      Ancestor Moth Wing  Cyrodilic Spadetail
# 1      Abecean Longfin       Ash Creep Cluster         Beehive Husk
# 2      Abecean Longfin       Ash Creep Cluster         Chaurus Eggs
# 3      Abecean Longfin       Ash Creep Cluster  Cyrodilic Spadetail
# 4      Abecean Longfin       Ash Creep Cluster            Elves Ear
# ...                ...                     ...                  ...
# 25237    Tundra Cotton              Void Salts                   NA
# 25238    Tundra Cotton          Wisp Wrappings                   NA
# 25239     Vampire Dust               White Cap                   NA
# 25240       Void Salts          Wisp Wrappings                   NA
# 25241            Wheat  Yellow Mountain Flower                   NA
#
#                                       effects                            name  \
# 0       [Fortify Restoration, Damage Stamina]   Potion of Fortify Restoration
# 1        [Fortify Sneak, Fortify Destruction]   Potion of Fortify Destruction
# 2          [Weakness to Poison, Invisibility]          Potion of Invisibility
# 3       [Fortify Restoration, Damage Stamina]   Potion of Fortify Restoration
# 4            [Weakness to Frost, Resist Fire]           Potion of Resist Fire
# ...                                       ...                             ...
# 25237         [Resist Magic, Fortify Magicka]       Potion of Fortify Magicka
# 25238                          [Resist Magic]          Potion of Resist Magic
# 25239                       [Restore Magicka]       Potion of Restore Magicka
# 25240                          [Resist Magic]          Potion of Resist Magic
# 25241  [Fortify Health, Damage Stamina Regen]  Poison of Damage Stamina Regen
#
#        value                                       descriptions
# 0        161  [Drain the target's Stamina by 18 points., Res...
# 1        269  [Destruction spells are 30% stronger for 60 se...
# 2        312  [Invisibility for 24 seconds., Target is 12% w...
# 3        161  [Drain the target's Stamina by 18 points., Res...
# 4        126  [Resist 18% of fire damage for 60 seconds., Ta...
# ...      ...                                                ...
# 25237    122  [Magicka is increased by 24 points for 60 seco...
# 25238     51               [Resist 6% of magic for 60 seconds.]
# 25239     25                    [Restore 30 points of Magicka.]
# 25240     51               [Resist 6% of magic for 60 seconds.]
# 25241    241  [Decrease the target's Stamina regeneration by...
#
# [25242 rows x 7 columns]

# %%
brews = list(brews_df.name)
ingredients = list(ingredients_df.name)

# %% [markdown]
# The model is the following:
#
# #### Parameters
#
# $B = \{1, \dots, 25242\}$: Set of brews
#
# $I = \{1, \dots, 109\}$: Set of ingredients
#
# $I_p \subset{I}$: Set of ingredients required to make one unit of brew $b$ (note that $|I_b| \leq 3 \,\,\forall b \in B$)
#
# $z_i \in \mathbb{Z}^+$: Amount of ingredient $i$ available
#
# $c_b \in \mathbb{R}^+$: gold value of brew $b$
#
# #### Decision Variables
#
# $y_b \in \mathbb{Z}^+$: Number of brews $b$ created
#
# $x_{ib} \in \mathbb{Z}^+$: Amount of ingredient $i$ used to create brew $b$
#
# #### Model
#
# $$ \max \sum_{i \in b} c_b y_p$$
# such that:
# $$y_b \leq x_{ib} \qquad \forall i \in I_b,  \forall b \in B$$
# $$\sum_{\{b \mid i \in I_b\}} x_{ib} \leq z_i \qquad \forall i \in I$$
#
#
# An additional sophistication for the model is to allow the purchase of common ingredients, which would amount to adding a integer decision variable for each such ingredient, adding them to the RHSs of the second constraints, and subtracting the costs in the objective.

# %%
B = [i for i in range(len(brews_df))]
I = [i for i in range(len(ingredients_df))]
c = np.array(brews_df['value'])

# %%
A = [[] for b in B]
for b in B:
    brew_ingredients = brews_df.loc[b][['first_ingredient','second_ingredient','third_ingredient']]
    for ingredient in brew_ingredients:
        if ingredient != 'NA':
            i = ingredients.index(ingredient)
            A[b].append(i)
            
# randomly generate inventory
z = np.random.poisson(lam=2, size=len(I))

# %% [markdown]
# Using Gurobi:

# %%
l = gp.tuplelist()
for b in B:
    for i in A[b]:
        l.append((b,i))
        
m = gp.Model('alchemy')
x = m.addVars(l, vtype=GRB.CONTINUOUS, name='x')
y = m.addVars(B, vtype=GRB.INTEGER, name='y')
m.addConstrs((y[b] <= x[b,i] for (b,i) in l), 'c1')
m.addConstrs((x.sum('*', i) <= z[i] for i in I))

m.setObjective(gp.quicksum(c[b]*y[b] for b in B), GRB.MAXIMIZE)
m.setParam('OUTPUT_FLAG',False)
m.optimize()

# %%
optimal_brews = [b for b in B if y[b].x > 0.5]
optimal_df = brews_df.loc[optimal_brews]
optimal_df['count'] = [int(y[b].x) for b in B if y[b].x > 0.5]
optimal_df.sort_values(by=['value'], ascending=False)
optimal_df = optimal_df[['name', 'count', 'value', 'first_ingredient', 'second_ingredient', 'third_ingredient', 'descriptions']]
optimal_df['value_count'] = optimal_df['value'] * optimal_df['count']
optimal_df = optimal_df.sort_values(by='value_count', ascending=False)
optimal_df
# Out:
#                                     name  count  value      first_ingredient  \
# 11281           Potion of Waterbreathing      1  24055         Chicken's Egg
# 7183           Potion of Fortify Stamina      2   4023             Boar Tusk
# 7126           Potion of Fortify Stamina      1   4116             Boar Tusk
# 18939           Potion of Fortify Health      1   3029           Giant's Toe
# 17724     Poison of Damage Stamina Regen      3    434         Frost Mirriam
# 2618                 Poison of Paralysis      2    428       Ashen Grass Pod
# 17032       Potion of Regenerate Magicka      2    374            Fire Salts
# 10009       Potion of Fortify Pickpocket      2    347  Charred Skeever Hide
# 22745       Potion of Regenerate Magicka      2    324         Jazbay Grapes
# 13698       Potion of Fortify Two-handed      2    301       Dragon's Tongue
# 19523     Poison of Damage Magicka Regen      1    584             Glow Dust
# 19410                Poison of Paralysis      1    582          Gleamblossom
# 8708      Poison of Damage Magicka Regen      1    559   Burnt Spriggan Wood
# 22083                Poison of Paralysis      1    523           Human Flesh
# 3138      Poison of Damage Magicka Regen      1    517            Bear Claws
# 13276        Potion of Regenerate Health      1    508          Daedra Heart
# 1796              Potion of Invisibility      1    506     Ash Creep Cluster
# 25009  Poison of Lingering Damage Health      2    251            Scathecraw
# 1041      Poison of Damage Magicka Regen      1    499    Ancestor Moth Wing
# 1328              Potion of Invisibility      1    491     Ash Creep Cluster
# 10585             Potion of Invisibility      1    490          Chaurus Eggs
# 12837                     Poison of Slow      1    485   Cyrodilic Spadetail
# 13733       Potion of Regenerate Stamina      1    475       Dragon's Tongue
# 13602                     Poison of Slow      1    475             Deathbell
# 9557                 Poison of Paralysis      1    467            Canis Root
# 1242              Potion of Invisibility      1    467     Ash Creep Cluster
# 1677      Poison of Damage Magicka Regen      1    459     Ash Creep Cluster
# 5133              Potion of Invisibility      1    456           Blisterwort
# 15111       Potion of Fortify Two-handed      1    455  Emperor Parasol Moss
# 21512        Potion of Regenerate Health      1    436              Histcarp
# 11280     Poison of Damage Magicka Regen      1    428         Chicken's Egg
# 648       Poison of Damage Magicka Regen      1    426    Ancestor Moth Wing
# 15218        Potion of Regenerate Health      1    411  Emperor Parasol Moss
# 17702     Poison of Damage Stamina Regen      1    388         Frost Mirriam
# 3110      Poison of Damage Magicka Regen      1    383            Bear Claws
# 7831                 Poison of Paralysis      1    381           Briar Heart
# 15433        Potion of Regenerate Health      1    360  Emperor Parasol Moss
# 14259       Potion of Regenerate Magicka      1    347           Dwarven Oil
# 18078       Potion of Regenerate Magicka      1    336           Frost Salts
# 826       Poison of Damage Magicka Regen      1    330    Ancestor Moth Wing
# 16433       Potion of Fortify Pickpocket      1    322            Falmer Ear
# 11403     Poison of Damage Magicka Regen      1    308         Chicken's Egg
# 1412              Potion of Invisibility      1    304     Ash Creep Cluster
# 59         Potion of Fortify Restoration      1    287       Abecean Longfin
# 14499     Poison of Damage Stamina Regen      1    255             Ectoplasm
# 21788     Poison of Damage Stamina Regen      1    239             Honeycomb
# 12855                     Poison of Fear      1    238   Cyrodilic Spadetail
# 16241            Potion of Resist Poison      1    225            Falmer Ear
# 9697             Potion of Resist Poison      1    225  Charred Skeever Hide
# 18789             Potion of Resist Shock      1    187          Giant Lichen
# 2378              Potion of Resist Shock      1    166      Ash Hopper Jelly
# 2476              Potion of Resist Shock      1    151      Ash Hopper Jelly
# 3861   Poison of Lingering Damage Health      1    150                   Bee
# 24267             Potion of Resist Shock      1    136                 Pearl
# 8909            Poison of Damage Magicka      1     73        Butterfly Wing
# 25217      Potion of Fortify Heavy Armor      1     55        Thistle Branch
#
#             second_ingredient       third_ingredient  \
# 11281              Hawk's Egg             Salmon Roe
# 7183            Large Antlers        Torchbug Thorax
# 7126                   Garlic      Slaughterfish Egg
# 18939        Glowing Mushroom                  Wheat
# 17724  Purple Mountain Flower                  Wheat
# 2618              Briar Heart            Human Flesh
# 17032              Moon Sugar            Snowberries
# 10009         Orange Dartwing      Slaughterfish Egg
# 22745     Red Mountain Flower                Taproot
# 13698    Emperor Parasol Moss             Void Salts
# 19523        Glowing Mushroom           Spriggan Sap
# 19410            Namira's Rot       Swamp Fungal Pod
# 8708                Salt Pile           Spriggan Sap
# 22083             Netch Jelly  Powdered Mammoth Tusk
# 3138         Eye of Sabre Cat           Hanging Moss
# 13276         Juniper Berries           Namira's Rot
# 1796                 Nirnroot         Wisp Wrappings
# 25009    Slaughterfish Scales         Thistle Branch
# 1041        Hagraven Feathers            Human Heart
# 1328                Bone Meal       Crimson Nirnroot
# 10585          Luna Moth Wing        Nordic Barnacle
# 12837            Poison Bloom              Salt Pile
# 13733             Fly Amanita         Scaly Pholiota
# 13602               Salt Pile                Taproot
# 9557         Rock Warbler Egg       Swamp Fungal Pod
# 1242             Beehive Husk         Luna Moth Wing
# 1677                Glow Dust             Spider Egg
# 5133         Crimson Nirnroot               Nirnroot
# 15111              Falmer Ear              Troll Fat
# 21512         Juniper Berries        Nordic Barnacle
# 11280              Hawk's Egg                     NA
# 648                Bear Claws       Rock Warbler Egg
# 15218            Gleamblossom             Void Salts
# 17702   Powdered Mammoth Tusk       Silverside Perch
# 3110            Chicken's Egg       Rock Warbler Egg
# 7831                Ectoplasm       Swamp Fungal Pod
# 15433         Nordic Barnacle    Red Mountain Flower
# 14259                 Taproot                     NA
# 18078              Moon Sugar                Taproot
# 826             Chicken's Egg          Hagraven Claw
# 16433         Orange Dartwing      Slaughterfish Egg
# 11403        Rock Warbler Egg             Spider Egg
# 1412             Chaurus Eggs       Rock Warbler Egg
# 59            Ashen Grass Pod          Small Antlers
# 14499                Histcarp          Large Antlers
# 21788           Large Antlers           Skeever Tail
# 12855   Powdered Mammoth Tusk          Small Antlers
# 16241               Grass Pod      Hagraven Feathers
# 9697               Falmer Ear      Hagraven Feathers
# 18789                   Pearl        Pine Thrush Egg
# 2378                Honeycomb                  Pearl
# 2476                    Pearl              White Cap
# 3861          Orange Dartwing             Scathecraw
# 24267         Pine Thrush Egg              White Cap
# 8909         Eye of Sabre Cat                     NA
# 25217               White Cap                     NA
#
#                                             descriptions  value_count
# 11281  [Decrease the target's Magicka regeneration by...        24055
# 7183   [Stamina is increased by 30 points for 300 sec...         8046
# 7126   [Stamina is increased by 30 points for 300 sec...         4116
# 18939  [Decrease the target's Stamina regeneration by...         3029
# 17724  [Decrease the target's Stamina regeneration by...         1302
# 2618   [You are 24% harder to detect for 60 seconds.,...          856
# 17032  [Magicka regenerates 30% faster for 300 second...          748
# 10009  [Pickpocketing is 24% easier for 60 seconds., ...          694
# 22745  [Magicka is increased by 24 points for 60 seco...          648
# 13698  [Causes 18 points of poison damage., Magicka i...          602
# 19523  [Decrease the target's Magicka regeneration by...          584
# 19410  [Creatures and people up to level 6 flee from ...          582
# 8708   [Decrease the target's Magicka regeneration by...          559
# 22083  [Creatures and people up to level 6 flee from ...          523
# 3138   [Drains the target's Magicka by 18 points., De...          517
# 13276  [Drains the target's Magicka by 18 points., De...          508
# 1796   [Drain the target's Stamina by 18 points., Des...          506
# 25009  [Increase Heavy Armor skill by 12 points for 6...          502
# 1041   [Drains the target's Magicka by 18 points., De...          499
# 1328   [Drain the target's Stamina by 54 points., Inv...          491
# 10585  [Drains the target's Magicka by 18 points., In...          490
# 12837  [Creatures and people up to level 6 flee from ...          485
# 13733  [Illusion spells are 24% stronger for 60 secon...          475
# 13602  [Magicka regenerates 30% faster for 300 second...          475
# 9557   [Drain the target's Stamina by 18 points., One...          467
# 1242   [Destruction spells are 30% stronger for 60 se...          467
# 1677   [Decrease the target's Magicka regeneration by...          459
# 5133   [Drain the target's Stamina by 54 points., Inv...          456
# 15111  [Causes 18 points of poison damage., Two-hande...          455
# 21512  [Decrease the target's Stamina regeneration by...          436
# 11280  [Decrease the target's Magicka regeneration by...          428
# 648    [Decrease the target's Magicka regeneration by...          426
# 15218  [Causes 18 points of poison damage., Magicka i...          411
# 17702  [Decrease the target's Stamina regeneration by...          388
# 3110   [Decrease the target's Magicka regeneration by...          383
# 7831   [Magicka is increased by 24 points for 60 seco...          381
# 15433  [Causes 18 points of poison damage., Magicka i...          360
# 14259  [Illusion spells are 24% stronger for 60 secon...          347
# 18078  [Magicka regenerates 30% faster for 300 second...          336
# 826    [Decrease the target's Magicka regeneration by...          330
# 16433  [Pickpocketing is 24% easier for 60 seconds., ...          322
# 11403  [Decrease the target's Magicka regeneration by...          308
# 1412   [Drain the target's Stamina by 18 points., Inv...          304
# 59     [Restoration spells are 24% stronger for 60 se...          287
# 14499  [Decrease the target's Stamina regeneration by...          255
# 21788  [Decrease the target's Stamina regeneration by...          239
# 12855  [Creatures and people up to level 6 flee from ...          238
# 16241  [Creatures and people up to level 6 will attac...          225
# 9697   [Creatures and people up to level 6 will attac...          225
# 18789  [Resist 18% of shock damage for 60 seconds., R...          187
# 2378   [Increases Light Armor skill by 12 points for ...          166
# 2476   [Resist 18% of shock damage for 60 seconds., R...          151
# 3861   [Causes 6 points of poison damage for 10 secon...          150
# 24267  [Resist 18% of shock damage for 60 seconds., R...          136
# 8909   [Drains the target's Magicka by 18 points., Re...           73
# 25217  [Increase Heavy Armor skill by 12 points for 6...           55

# %%
print(f"Optimal Objective Value: {int(m.objVal)}")
# Out:
# Optimal Objective Value: 61143

# %%
optimal_df.loc[11281].descriptions
# Out:
# ["Decrease the target's Magicka regeneration by 100% for 30 seconds.",
#  "Drain the target's Stamina by 6 points per second for 10 seconds.",
#  'Resist 6% of magic for 60 seconds.',
#  'Can breathe underwater for 359 seconds.']
